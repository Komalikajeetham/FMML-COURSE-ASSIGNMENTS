# %% [markdown]
# <a href="https://colab.research.google.com/github/Komalikajeetham/FMML-COURSE-ASSIGNMENTS/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# <table class="tfo-notebook-buttons" align="left">
#   <td>
#     <a target="_blank" href="https://colab.research.google.com/drive/1TuDbIyso6irdyBFgaHRpC-PxUICWPHcS?usp=sharing"><img height="32px" src="https://colab.research.google.com/img/colab_favicon.ico" />Run in Google Colab</a>
#   </td>
#   <td>
#     <a target="_blank" href="https://github.com/Foundations-in-Modern-Machine-Learning/course-contents/tree/main/Bayesian/"><img src="https://www.tensorflow.org/images/GitHub-Mark-32px.png" />View source on GitHub</a>
#   </td>
# </table>
# <br>
# <br>
# <br>

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2023-05-24 11:41:12--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.110.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   116MB/s    in 0.6s
#
# 2023-05-24 11:41:14 (116 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False), 
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split() 
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 22377  1605.01779v1  With the recent popularity of graphical cluste...  stat
# 21774   1309.2895v1  Regularized principal components analysis, esp...  stat
# 24842   1412.2697v1  This paper deals with a reduced reference (RR)...    cs
# 8227    1312.5697v2  Object recognition and localization are import...    cs
# 9088   cs/0212032v1  This paper presents a simple unsupervised lear...    cs
# ...             ...                                                ...   ...
# 12056  1707.00536v2  Recommendation is the task of improving custom...    cs
# 11546  1605.08455v1  Performance of nuclear threat detection system...    cs
# 5626   1505.02294v3  Analysis of non-asymptotic estimation error an...  stat
# 5288    1209.5477v2  In Natural Language Processing (NLP) tasks, da...  stat
# 22116   1412.7638v1  Given $n$ i.i.d. observations of a random vect...  stat
#
#                                                    title  year  \
# 22377  Clustering on the Edge: Learning Structure in ...  2016
# 21774  Sparse and Functional Principal Components Ana...  2013
# 24842  Image quality assessment measure based on natu...  2014
# 8227   Using Web Co-occurrence Statistics for Improvi...  2013
# 9088   Thumbs Up or Thumbs Down? Semantic Orientation...  2002
# ...                                                  ...   ...
# 12056  Robust Cost-Sensitive Learning for Recommendat...  2017
# 11546  Suppressing Background Radiation Using Poisson...  2016
# 5626                 Estimation with Norm Regularization  2015
# 5288   Optimal Weighting of Multi-View Data with Low ...  2012
# 22116  Inference for Sparse Conditional Precision Mat...  2014
#
#                                                 keywords
# 22377  [popularity, graphical, clustering, increased,...
# 21774  [regularized, principal, components, especiall...
# 24842  [reference, statistics, transform, convenient,...
# 8227   [recognition, localization, important, incorpo...
# 9088   [unsupervised, algorithm, classifying, recomme...
# ...                                                  ...
# 12056  [recommendation, improving, experience, person...
# 11546  [performance, detection, spectrometry, attribu...
# 5626   [asymptotic, estimation, structured, statistic...
# 5288   [processing, following, properties, successful...
# 22116  [observations, dimensional, dimensional, estim...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 22377    [popularity, graphical, clustering, increased,...
# 21774    [regularized, principal, components, especiall...
# 24842    [reference, statistics, transform, convenient,...
# 8227     [recognition, localization, important, incorpo...
# 9088     [unsupervised, algorithm, classifying, recomme...
#                                ...
# 28830    [approaches, selection, classification, signif...
# 37153    [partially, observable, processes, abstracts, ...
# 13367    [algorithm, optimization, technique, principle...
# 22747    [diffusion, distribution, establish, diffusion...
# 8342     [meaningful, representations, designing, effic...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]), 
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8788 words.
# Out of those 4528 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="3c014800-3104-44bf-890b-b17fa73b72b4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3c014800-3104-44bf-890b-b17fa73b72b4")) {                    Plotly.newPlot(                        "3c014800-3104-44bf-890b-b17fa73b72b4",                        [{"x":["popularity","increased","simultaneously","applications","particularly","clustering","information","resolution","extension","structure","instances","discovery","addresses","naturally","community","segmentation","partition","determines","likelihood","graphical","correlation","especially","functional","simulated","regularized","selection","activation","encourage","components","optimization","interpretable","demonstrate","neuroimaging","estimating","introduce","foundation","generalizes","principal","dimensional","combinations","approaches","multivariate","spatially","smoothness","reduction","dimension","framework","regularization","particular","improvements","statistics","dependencies","distorted","degradation","reference","coefficients","structures","transform","divergence","convenient","geometric","assessment","statistical","according","occurrences","recognition","incorporation","surrogate","simplicity","localization","concretely","improving","knowledge","occurrence","resulting","documents","categorization","effective","detection","procedure","combining","inference","contextual","important","predictions","encapsulate","classifiers","significant","predicted","classification","excellent","classifying","classified","different","unsupervised","orientation","associations","algorithm","automobile","calculated","evaluated","adjectives","recommended","observation","sentiment","recommendation","attentions","personalized","connected","sufficient","representations","convolutional","attracting","promising","satisfactory","potential","questions","observational","essential","differences","observing","affirmative","transport","commonalities","population","populations","explorations","empirical","scientific","representation","conducted","environments","expressing","procedures","experimental","generalizability","derivations","embedding","specifically","parametric","adjacency","approximate","iteratively","probability","performance","probabilistic","translation","recurrent","distribution","captioning","formalism","artifacts","theoretic","illustrative","understand","densities","restriction","considered","communities","thresholds","fundamental","probabilities","parameters","homogenous","stochastic","circumstances","generalizations","connection","implications","computational","polylogarithmic","generality","understanding","heterogeneous","recovering","extracting","individually","classifier","fractional","respectively","similarity","strategies","deformation","hierarchical","supervision","challenging","experiments","appearance","inaccurate","supervised","predicting","efficiency","obtaining","registration","unbalanced","technique","automatically","numerical","dirichlet","presented"],"y":[21,45,107,440,73,138,699,119,74,345,100,49,40,63,73,225,21,14,66,63,57,127,54,43,34,163,42,16,94,313,30,560,7,68,327,19,36,36,191,42,459,25,24,18,99,55,546,91,273,122,58,48,10,16,52,28,130,65,25,15,73,45,157,116,17,402,11,13,24,60,5,103,336,29,130,80,25,256,348,109,108,209,53,340,74,4,105,237,54,502,29,47,24,758,151,41,12,785,2,27,144,2,1,72,55,24,7,7,71,54,228,369,8,117,18,146,64,6,71,59,22,1,9,4,41,5,1,166,38,350,66,79,19,38,383,5,1,98,189,43,2,100,30,187,901,166,112,149,208,17,25,14,50,9,63,9,14,117,21,4,77,74,252,2,137,9,5,51,30,284,0,8,147,36,17,55,12,145,6,89,155,113,14,95,49,264,619,80,12,207,87,180,26,32,2,265,181,79,20,170],"type":"bar"},{"x":["popularity","increased","simultaneously","applications","particularly","c ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4528,), (4528, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.81

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Factorized</span> <span style=''>Multi</span> <span style=''>Modal</span> <span style=''>Topic</span> <span style=''>Model</span> <br/><br/><span style=''>Multi</span> <span style=''>modal</span> <span style=''>data</span> <span style='background-color:rgba(0, 255, 0, 0.4000000000000001);'>collections</span> <span style=''>such</span> <span style=''>as</span> <span style=''>corpora</span> <span style=''>of</span> <span style=''>paired</span> <span style=''>images</span> <span style=''>and</span> <span style=''>text</span> <span style=''>snippets</span> <span style=''>require</span> <span style=''>analysis</span> <span style=''>methods</span> <span style=''>beyond</span> <span style=''>single</span> <span style=''>view</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>component</span> <span style=''>and</span> <span style=''>topic</span> <span style=''>models</span> <span style=''>For</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>continuous</span> <span style='background-color:rgba(255, 0, 0, 0.38271604938271614);'>observations</span> <span style=''>the</span> <span style=''>current</span> <span style=''>dominant</span> <span style=''>approach</span> <span style=''>is</span> <span style=''>based</span> <span style=''>on</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>extensions</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>canonical</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>correlation</span> <span style=''>analysis</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>factorizing</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>variation</span> <span style=''>into</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>components</span> <span style=''>shared</span> <span style=''>by</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.326334208223972);'>different</span> <span style='background-color:rgba(0, 255, 0, 0.5897435897435899);'>modalities</span> <span style=''>and</span> <span style=''>those</span> <span style=''>private</span> <span style=''>to</span> <span style=''>each</span> <span style=''>of</span> <span style=''>them</span> <span style=''>For</span> <span style=''>count</span> <span style=''>data</span> <span style=''>multiple</span> <span style=''>variants</span> <span style=''>of</span> <span style=''>topic</span> <span style=''>models</span> <span style='background-color:rgba(0, 255, 0, 0.3333333333333334);'>attempting</span> <span style=''>to</span> <span style=''>tie</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.5897435897435899);'>modalities</span> <span style=''>together</span> <span style=''>have</span> <span style=''>been</span> <span style='background-color:rgba(0, 255, 0, 0.31782945736434115);'>presented</span> <span style=''>All</span> <span style=''>of</span> <span style=''>these</span> <span style=''>however</span> <span style=''>lack</span> <span style=''>the</span> <span style=''>ability</span> <span style=''>to</span> <span style=''>learn</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>components</span> <span style=''>private</span> <span style=''>to</span> <span style=''>one</span> <span style=''>modality</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>consequently</span> <span style=''>will</span> <span style=''>try</span> <span style=''>to</span> <span style=''>force</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>dependencies</span> <span style=''>even</span> <span style=''>between</span> <span style='background-color:rgba(0, 255, 0, 0.4000000000000001);'>minimally</span> <span style=''>correlating</span> <span style='background-color:rgba(0, 255, 0, 0.5897435897435899);'>modalities</span> <span style=''>In</span> <span style=''>this</span> <span style=''>work</span> <span style= ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Fast</span> <span style=''>and</span> <span style=''>Robust</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Recursive</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Algorithms</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Separable</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Nonnegative</span> <span style=''>Matrix</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Factorization</span> <br/><br/><span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>study</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>nonnegative</span> <span style=''>matrix</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>factorization</span> <span style=''>problem</span> <span style=''>under</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>separability</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>assumption</span> <span style=''>(that</span> <span style=''>is</span> <span style=''>there</span> <span style=''>exists</span> <span style=''>a</span> <span style=''>cone</span> <span style=''>spanned</span> <span style=''>by</span> <span style=''>a</span> <span style=''>small</span> <span style=''>subset</span> <span style=''>of</span> <span style=''>the</span> <span style=''>columns</span> <span style=''>of</span> <span style=''>the</span> <span style=''>input</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>nonnegative</span> <span style=''>data</span> <span style=''>matrix</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>containing</span> <span style=''>all</span> <span style=''>columns)</span> <span style=''>which</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>equivalent</span> <span style=''>to</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>hyperspectral</span> <span style=''>unmixing</span> <span style=''>problem</span> <span style=''>under</span> <span style=''>the</span> <span style=''>linear</span> <span style=''>mixing</span> <span style=''>model</span> <span style=''>and</span> <span style=''>the</span> <span style=''>pure</span> <span style=''>pixel</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>assumption</span> <span style=''>We</span> <span style=''>present</span> <span style=''>a</span> <span style=''>family</span> <span style=''>of</span> <span style=''>fast</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>recursive</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithms</span> <span style=''>and</span> <span style=''>prove</span> <span style=''>they</span> <span style=''>are</span> <span style=''>robust</span> <span style=''>under</span> <span style=''>any</span> <span style=''>small</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>perturbations</span> <span style=''>of</span> <span style=''>the</span> <span style=''>input</span> <span style=''>data</span> <span style=''>matrix</span> <span style=''>This</span> <span style=''>family</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generalizes</span> <span style=''>several</span> <span style=''>existing</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>hyperspectral</span> <span style=''>unmixing</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithms</span> <span style=''>and</span> <span style=''>hence</span> <span style=''>provides</span> <span style=''>for</span> <span style=''>the</span> <span style=''>first</span> <span style=''>time</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>theoretical</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>justification</span> <span style=''>of</span> <span style=''>their</span> <span style=''>better</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>pra ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Using</span> <span style=''>Temporal</span> <span style=''>Data</span> <span style=''>for</span> <span style=''>Making</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Recommendations</span> <br/><br/><span style=''>We</span> <span style=''>treat</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>collaborative</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>filtering</span> <span style=''>as</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.75);'>univariate</span> <span style=''>time</span> <span style=''>series</span> <span style='background-color:rgba(255, 0, 0, 0.3142857142857143);'>estimation</span> <span style=''>problem</span> <span style=''>given</span> <span style=''>a</span> <span style=''>users</span> <span style=''>previous</span> <span style=''>votes</span> <span style=''>predict</span> <span style=''>the</span> <span style=''>next</span> <span style=''>vote</span> <span style=''>We</span> <span style=''>describe</span> <span style=''>two</span> <span style=''>families</span> <span style=''>of</span> <span style=''>methods</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>transforming</span> <span style=''>data</span> <span style=''>to</span> <span style=''>encode</span> <span style=''>time</span> <span style=''>order</span> <span style=''>in</span> <span style=''>ways</span> <span style=''>amenable</span> <span style=''>to</span> <span style=''>off</span> <span style=''>the</span> <span style=''>shelf</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>classification</span> <span style=''>and</span> <span style=''>density</span> <span style='background-color:rgba(255, 0, 0, 0.3142857142857143);'>estimation</span> <span style=''>tools</span> <span style=''>and</span> <span style=''>examine</span> <span style=''>the</span> <span style=''>results</span> <span style=''>of</span> <span style=''>using</span> <span style=''>these</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approaches</span> <span style=''>on</span> <span style=''>several</span> <span style=''>real</span> <span style=''>world</span> <span style=''>data</span> <span style=''>sets</span> <span style=''>The</span> <span style='background-color:rgba(0, 255, 0, 0.44378698224852076);'>improvements</span> <span style=''>in</span> <span style='background-color:rgba(255, 0, 0, 0.46464646464646464);'>predictive</span> <span style=''>accuracy</span> <span style=''>we</span> <span style=''>realize</span> <span style='background-color:rgba(255, 0, 0, 0.33333333333333326);'>recommend</span> <span style=''>the</span> <span style=''>use</span> <span style=''>of</span> <span style=''>other</span> <span style='background-color:rgba(255, 0, 0, 0.46464646464646464);'>predictive</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>that</span> <span style=''>exploit</span> <span style=''>the</span> <span style=''>temporal</span> <span style=''>order</span> <span style=''>of</span> <span style=''>data</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Visualizing</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Interacting</span> <span style=''>with</span> <span style=''>Concept</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Hierarchies</span> <br/><br/><span style=''>Concept</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Hierarchies</span> <span style=''>and</span> <span style=''>Formal</span> <span style=''>Concept</span> <span style=''>Analysis</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>theoretically</span> <span style=''>well</span> <span style=''>grounded</span> <span style=''>and</span> <span style=''>largely</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>experimented</span> <span style=''>methods</span> <span style=''>They</span> <span style=''>rely</span> <span style=''>on</span> <span style=''>line</span> <span style=''>diagrams</span> <span style=''>called</span> <span style=''>Galois</span> <span style=''>lattices</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>visualizing</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>analysing</span> <span style=''>object</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>attribute</span> <span style=''>sets</span> <span style=''>Galois</span> <span style=''>lattices</span> <span style=''>are</span> <span style=''>visually</span> <span style=''>seducing</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>conceptually</span> <span style=''>rich</span> <span style=''>for</span> <span style=''>experts</span> <span style=''>However</span> <span style=''>they</span> <span style=''>present</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>important</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>drawbacks</span> <span style=''>due</span> <span style=''>to</span> <span style=''>their</span> <span style=''>concept</span> <span style=''>oriented</span> <span style=''>overall</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>structure</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>analysing</span> <span style=''>what</span> <span style=''>they</span> <span style=''>show</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>difficult</span> <span style=''>for</span> <span style=''>non</span> <span style=''>experts</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>navigation</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>cumbersome</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>interaction</span> <span style=''>is</span> <span style=''>poor</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>scalability</span> <span style=''>is</span> <span style=''>a</span> <span style=''>deep</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>bottleneck</span> <span style=''>for</span> <span style=''>visual</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>interpretation</span> <span style=''>even</span> <span style=''>for</span> <span style=''>experts</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>introduce</span> <span style=''>semantic</span> <span style=''>probes</span> <span style=''>as</span> <span style=''>a</span> <span style=''>means</span> <span style=''>to</span> <span style=''>overcome</span> <span style=''>many</span> <span style=''>of</span> <span style=''>these</span> <span style=''>problems</span> <span style=''>and</span> <span style=''>extend</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>usability</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>application</span> <span style='background-color:rgba ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	representation (0.12562814070351758)
# 	processing (0.10301507537688442)
# 	architecture (0.09332376166547021)
# 	segmentation (0.08076094759511845)
# 	experimental (0.13747307968413497)
# 	information (0.250897343862168)
# 	detection (0.1249102656137832)
# 	different (0.27207465900933236)
# 	convolutional (0.13244795405599424)
# 	recognition (0.14429289303661164)
#
# Some Statistics words are:
# 	statistical (0.14299900695134063)
# 	theoretical (0.14697120158887786)
# 	stochastic (0.141012909632572)
# 	variables (0.14051638530287985)
# 	algorithm (0.3833167825223436)
# 	estimation (0.17130089374379345)
# 	distribution (0.18570009930486595)
# 	dimensional (0.18818272095332672)
# 	inference (0.2015888778550149)
# 	regression (0.1861966236345581)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]), 
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="da51ca95-7c03-405f-8035-6b626574caad" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("da51ca95-7c03-405f-8035-6b626574caad")) {                    Plotly.newPlot(                        "da51ca95-7c03-405f-8035-6b626574caad",                        [{"x":["popularity","increased","simultaneously","applications","particularly","clustering","information","resolution","extension","structure","instances","discovery","addresses","naturally","community","segmentation","partition","determines","likelihood","graphical","correlation","especially","functional","simulated","regularized","selection","activation","encourage","components","optimization","interpretable","demonstrate","neuroimaging","estimating","introduce","foundation","generalizes","principal","dimensional","combinations","approaches","multivariate","spatially","smoothness","reduction","dimension","framework","regularization","particular","improvements","statistics","dependencies","distorted","degradation","reference","coefficients","structures","transform","divergence","convenient","geometric","assessment","statistical","according","occurrences","recognition","incorporation","surrogate","simplicity","localization","concretely","improving","knowledge","occurrence","resulting","documents","categorization","effective","detection","procedure","combining","inference","contextual","important","predictions","encapsulate","classifiers","significant","predicted","classification","excellent","classifying","classified","different","unsupervised","orientation","associations","algorithm","automobile","calculated","evaluated","adjectives","recommended","observation","sentiment","recommendation","attentions","personalized","connected","sufficient","representations","convolutional","attracting","promising","satisfactory","potential","questions","observational","essential","differences","observing","affirmative","transport","commonalities","population","populations","explorations","empirical","scientific","representation","conducted","environments","expressing","procedures","experimental","generalizability","derivations","embedding","specifically","parametric","adjacency","approximate","iteratively","probability","performance","probabilistic","translation","recurrent","distribution","captioning","formalism","artifacts","theoretic","illustrative","understand","densities","restriction","considered","communities","thresholds","fundamental","probabilities","parameters","homogenous","stochastic","circumstances","generalizations","connection","implications","computational","polylogarithmic","generality","understanding","heterogeneous","recovering","extracting","individually","classifier","fractional","respectively","similarity","strategies","deformation","hierarchical","supervision","challenging","experiments","appearance","inaccurate","supervised","predicting","efficiency","obtaining","registration","unbalanced","technique","automatically","numerical","dirichlet","presented","objective","extremely","efficient","available","algorithms","posterior","association","considering","expresses","discriminant","regression","correlated","variables","situation","advantage","identification","relationships","represent","scleroderma","trajectories","treatments","individual","trajectory","predictive","subpopulation","observations","continuous","accurately","exploiting","individuals","clinicians","resolutions","challenge","describing","autoimmune","dynamically","computing","constraints","computationally","implement","signaling","leveraging","necessary","processing","asynchronous","connections","multilayer","complexity","expensive","implementation","optoelectronic","electrical","detectors","mechanism","overcomes","compu ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	polylogarithmic
# 	scleroderma
# 	subpopulation
# 	autoimmune
# 	reparameterizing
# 	sparsities
# 	ellipsoid
# 	ellipsoidal
# 	parallelisation
# 	resistance
# 	breaching
# 	unfavorable
# 	ferromagnetic
# 	contamination
# 	spectroscopy
# 	nonparametrics
# 	misclassify
# 	seasonality
# 	corporation
# 	morgenstern
# Some words which never appear in Statistics papers:
# 	adjectives
# 	deformation
# 	optoelectronic
# 	propositional
# 	calligraphy
# 	authoring
# 	deductive
# 	formalisms
# 	monocular
# 	localizing
# 	solvability
# 	synchronized
# 	availabilities
# 	immediate
# 	reproduction
# 	photographic
# 	substitution
# 	emotional
# 	achievements
# 	dominating

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.0875632950475484e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7725
